# %% [markdown]
# # This is the title

# %% [markdown]
# This is some text

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
pd.__path__
# Out:
# ['/Users/stephaniezhu/opt/anaconda3/lib/python3.7/site-packages/pandas']

# %%
mvp_2019 = pd.read_csv('mvp_data/mvp_2019.csv')

# %%
mvp_2019[:10]
# Out:
#                   Player  Age   Tm  First  Pts Won  Pts Max  Share   G    MP  \
# 0  Giannis Antetokounmpo   24  MIL   78.0    941.0     1010  0.932  72  32.8
# 1           James Harden   29  HOU   23.0    776.0     1010  0.768  78  36.8
# 2            Paul George   28  OKC    0.0    356.0     1010  0.352  77  36.9
# 3           Nikola Jokić   23  DEN    0.0    212.0     1010  0.210  80  31.3
# 4          Stephen Curry   30  GSW    0.0    175.0     1010  0.173  69  33.8
# 5         Damian Lillard   28  POR    0.0     69.0     1010  0.068  80  35.5
# 6            Joel Embiid   24  PHI    0.0     49.0     1010  0.049  64  33.7
# 7           Kevin Durant   30  GSW    0.0     25.0     1010  0.025  78  34.6
# 8          Kawhi Leonard   27  TOR    0.0     13.0     1010  0.013  60  34.0
# 9      Russell Westbrook   30  OKC    0.0      8.0     1010  0.008  73  36.0
#
#     PTS   TRB   AST  STL  BLK    FG%    3P%    FT%    WS  WS/48  mvp_year
# 0  27.7  12.5   5.9  1.3  1.5  0.578  0.256  0.729  14.4  0.292      2019
# 1  36.1   6.6   7.5  2.0  0.7  0.442  0.368  0.879  15.2  0.254      2019
# 2  28.0   8.2   4.1  2.2  0.4  0.438  0.386  0.839  11.9  0.201      2019
# 3  20.1  10.8   7.3  1.4  0.7  0.511  0.307  0.821  11.8  0.226      2019
# 4  27.3   5.3   5.2  1.3  0.4  0.472  0.437  0.916   9.7  0.199      2019
# 5  25.8   4.6   6.9  1.1  0.4  0.444  0.369  0.912  12.1  0.205      2019
# 6  27.5  13.6   3.7  0.7  1.9  0.484  0.300  0.804   8.7  0.194      2019
# 7  26.0   6.4   5.9  0.7  1.1  0.521  0.353  0.885  11.5  0.204      2019
# 8  26.6   7.3   3.3  1.8  0.4  0.496  0.371  0.854   9.5  0.224      2019
# 9  22.9  11.1  10.7  1.9  0.5  0.428  0.290  0.656   6.8  0.124      2019

# %%
colormap = plt.cm.PiYG
plt.figure(figsize=(12,12))
plt.title('Pearson Correlation of Features', y=1.2, size=18)
sns.heatmap(mvp_2019_sl.corr().round(2), linewidths=0.1, vmax=1.0, square=True, cmap=colormap, \
            linecolor='white', annot=True);

# %%
mvp_2019_sl = mvp_2019[['Player', 'Tm', 'Share', 'G', 'MP', 'PTS', 'TRB', 'AST', 'FG%']]
mvp_2019_sl = mvp_2019_sl[:10]

# %%
mvp_2019_sl['MVP'] = 1

# %%
season_2019 = pd.read_csv('season_data/per_game_2019.csv')

# %%
# limit_df = season_2019[['Player', 'Tm', 'G', 'MP', 'PTS', 'TRB', 'AST', 'FG%']]

# %%
merged_df = season_2019.merge(mvp_2019_sl[['Player', 'MVP']], how='outer', left_on='Player', right_on='Player')

# %%
merged_df2 = merged_df.fillna(0)

# %%
merged_df2
# Out:
#            Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  TRB  \
# 0    Álex Abrines  SG   25  OKC  31   2  19.0  1.8   5.1  0.357  ...  1.5
# 1      Quincy Acy  PF   28  PHO  10   0  12.3  0.4   1.8  0.222  ...  2.5
# 2    Jaylen Adams  PG   22  ATL  34   1  12.6  1.1   3.2  0.345  ...  1.8
# 3    Steven Adams   C   25  OKC  80  80  33.4  6.0  10.1  0.595  ...  9.5
# 4     Bam Adebayo   C   21  MIA  82  28  23.3  3.4   5.9  0.576  ...  7.3
# ..            ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...  ...
# 525    Trae Young  PG   20  ATL  81  81  30.9  6.5  15.5  0.418  ...  3.7
# 526   Cody Zeller   C   26  CHO  49  47  25.4  3.9   7.0  0.551  ...  6.8
# 527  Tyler Zeller   C   29  TOT   6   1  15.5  2.7   5.0  0.533  ...  4.0
# 528    Ante Žižić   C   22  CLE  59  25  18.3  3.1   5.6  0.553  ...  5.4
# 529   Ivica Zubac   C   21  TOT  59  37  17.6  3.6   6.4  0.559  ...  6.1
#
#      AST  STL  BLK  TOV   PF   PTS  season_start  season_end  MVP
# 0    0.6  0.5  0.2  0.5  1.7   5.3          2019        2020  0.0
# 1    0.8  0.1  0.4  0.4  2.4   1.7          2019        2020  0.0
# 2    1.9  0.4  0.1  0.8  1.3   3.2          2019        2020  0.0
# 3    1.6  1.5  1.0  1.7  2.6  13.9          2019        2020  0.0
# 4    2.2  0.9  0.8  1.5  2.5   8.9          2019        2020  0.0
# ..   ...  ...  ...  ...  ...   ...           ...         ...  ...
# 525  8.1  0.9  0.2  3.8  1.7  19.1          2019        2020  0.0
# 526  2.1  0.8  0.8  1.3  3.3  10.1          2019        2020  0.0
# 527  0.7  0.2  0.5  0.7  3.3   7.7          2019        2020  0.0
# 528  0.9  0.2  0.4  1.0  1.9   7.8          2019        2020  0.0
# 529  1.1  0.2  0.9  1.2  2.3   8.9          2019        2020  0.0
#
# [530 rows x 32 columns]

# %%
y = merged_df2['MVP']
X = merged_df2[['G', 'MP', 'PTS', 'TRB', 'AST']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression(solver='liblinear')
logreg.fit(X_train, y_train)
logreg.score(X_test, y_test)
# Out:
# 0.9774436090225563

# %%
y_trpred = logreg.predict(X_train)

# %%
print(sklearn.metrics.accuracy_score(y_train, y_trpred))
print(sklearn.metrics.f1_score(y_train, y_trpred))
print(sklearn.metrics.recall_score(y_train, y_trpred))
print(sklearn.metrics.precision_score(y_train, y_trpred))
# Out:
# 0.9974811083123426
# 0.9090909090909091
# 0.8333333333333334
# 1.0

# %%
print(sklearn.metrics.accuracy_score(y_test, y_pred))
print(sklearn.metrics.f1_score(y_test, y_pred))
print(sklearn.metrics.recall_score(y_test, y_pred))
print(sklearn.metrics.precision_score(y_test, y_pred))
# Out:
# 0.9774436090225563
# 0.4
# 0.25
# 1.0

# %%
y_pred = logreg.predict(X_test)

# %%
df_y_pred = pd.DataFrame(y_pred, columns=['pred']).reset_index(drop=True)
df_y_test = y_test.to_frame(name='test').reset_index(drop=True)
df_y = pd.concat([df_y_pred, df_y_test], axis=1)

# %%
import sklearn.metrics

# %%
y_test[y_test == 1]
# Out:
# 123    1.0
# 149    1.0
# 154    1.0
# 304    1.0
# Name: MVP, dtype: float64

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=500)
rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.9699248120300752

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=4)
knn.fit(X_train, y_train)
knn.score(X_test, y_test)
# Out:
# 0.9699248120300752

# %%
from sklearn.svm import SVC, LinearSVC

svc = SVC()
svc.fit(X_train, y_train)
svc.score(X_test, y_test)
# Out:
# /Users/stephaniezhu/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.9924812030075187

# %%
X_train
# Out:
#       G    MP   PTS  TRB  AST
# 181  69  26.7  13.7  6.8  2.6
# 211  82  34.7  20.0  7.9  2.8
# 92   44  25.2  10.3  7.0  1.8
# 226  60  21.7   7.6  2.5  2.3
# 376  77  13.7   4.9  4.2  0.6
# ..   ..   ...   ...  ...  ...
# 15   25  12.9   2.5  2.2  0.8
# 8    10  12.0   3.7  2.6  1.3
# 235  68  29.0  13.6  6.7  4.2
# 90   39  14.8   4.4  1.7  1.8
# 266  57  26.8  10.9  3.0  2.9
#
# [397 rows x 5 columns]
