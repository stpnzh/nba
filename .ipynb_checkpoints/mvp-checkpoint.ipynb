# %% [markdown]
# # Testing for MVP
#
# Some blurb here.

# %% [markdown]
# ## Define the problem
#
# - What are we trying to solve?
# - What's the current method?
# - Why does the current method need improvement?
# - What should the output be? What should the deliverable look like?
# - What is the selection criteria? For instance, do we need accuracy to be at least 99% for the model to be accepted?
# - What will the information used for and should it be repeatable? How often?
#
# - This is a supervised learning problem since we have labeled data. Within supervised learning, this is a classification problem.
# - This is a binary classification problem since we are trying to predict 0 or 1.

# %% [markdown]
# ## 2. Get the data
#
# In business environments it's common for data to be held in a relational database. To access the data we may need the correct access authorizations and credentials as well as an idea of the data schema.
#
# It is best to create a function to load the data especially if the data changes regularly.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# create function to read in files
def importGlobbedFiles(path):
    globbed_files = glob.glob(path + '/*.csv')
    list_of_dfs = []
    for csv in globbed_files:
        df = pd.read_csv(csv)
        list_of_dfs.append(df)
    return pd.concat(list_of_dfs)

# %%
df_basic = importGlobbedFiles('data_historical_basic_stats')
df_adv = importGlobbedFiles('data_historical_adv_stats')
df_mvp = importGlobbedFiles('data_historical_mvp')

# %% [markdown]
# ## 3. Do some exploratory data analysis (EDA)
#
# - check out the data structure
# - check for numeric columns vs object (text) columns. At some point, would the object columns be dropped as features? Or do we have to encode them as categories?
# - data visualization:
#     - you can plot a histogram to get a quick feel for each numerical attribute. The horizontal axis represents the value range and the vertical axis represents the number of instances.

# %%
# check out the data
# df_basic.head()
# df_adv.head()
# df_mvp.head()
# df_basic.info()

# %%
# adjust feature names to lowercase and remove whitespace
def adjustFeatureNames(df):
    df.columns = df.columns.str.lower().str.replace(' ', '_')
    
for df in [df_basic, df_adv, df_mvp]:
    adjustFeatureNames(df)

# %%
# there are some * associated with player names. this function will remove them
def cleanSomeFeatures(df):
    df['player'] = df['player'].str.replace('*','')
    
for df in [df_basic, df_adv, df_mvp]:
    cleanSomeFeatures(df)

# %%
# plot a historgram for each numerical feature
# %matplotlib inline
# df_basic.hist(figsize=(15,15))
# plt.show;

# %%
# from pandas.plotting import scatter_matrix

# attributes = ['vorp', 'bpm', 'ws/48']
# scatter_matrix(df_adv[attributes], figsize=(12,8))
# plt.show();

# %% [markdown]
# ## Prepare the data for machine learning
#
# - Combine dataframes as needed.
# - Clean data:
#     - Deal with missing values. Options: remove entire features with NaNs. Remove observations with NaNs. Set NaNs to some value (0, mean, median.. be careful if you're applying means or medians to the entire dataset). If using mean or median, save the value to replace NaNs in the test set.
#     - Encode categorical or ordinal data, if these features are kept.
# - Do you need to do any feature engineering (extraction)? Should original features be transformed in a way that strengthens its predictive power?
# - More EDA as needed
#
# ### feature selection, feature engineering
#  - remember to split data into training and test sets before doing any feature selection!
#  - min-max scaling/normalization = x-min/(max-min) <- value between (0,1)
#  - standardization = x-mean/sd <- standardized values always have 0 mean. less affected by outliers.
# ### create transformation pipelines

# %%
# make a copy of df_mvp
df_mvp_prep = df_mvp.copy()

# add new feature to signify which players were on the mvp shortlist
df_mvp_prep['short_list'] = 1

# add new feature to signify which player in the shortlist won mvp
df_mvp_tmp = df_mvp_prep.groupby('mvp_year').max()[['share']].reset_index()
df_mvp_tmp['mvp'] = 1
df_mvp_prep = df_mvp_prep.merge(df_mvp_tmp, how='outer', on=['mvp_year', 'share'])

# fill NaN with 0
df_mvp_prep['mvp'].fillna(0, inplace=True)

# %%
# combine all dataframes: basic, advanced, mvp

df_basic_tmp = df_basic[['player', 'tm', 'season_end', 'g', 'gs', 'mp'
                         , 'fg%', 'efg%', 'trb', 'ast', 'stl'
                         , 'blk', 'tov', 'pf', 'pts']]

df_adv_tmp = df_adv[['player', 'tm', 'season_end', 'per', 'ts%', 'usg%'
                     , 'ws/48', 'bpm', 'vorp']]

df_mvp_tmp = df_mvp_prep[['player', 'tm', 'mvp_year', 'share', 'short_list', 'mvp']]

df_basic_adv_tmp = df_basic_tmp.merge(df_adv_tmp, how='left', on=['player', 'tm', 'season_end'])

df_all_stats = df_basic_adv_tmp.merge(df_mvp_tmp, how='left' , left_on=['player', 'tm', 'season_end']
                     , right_on=['player', 'tm', 'mvp_year'])

df_all_stats.fillna(0, inplace=True)

# %%
# colormap = plt.cm.Greens
# plt.figure(figsize=(16,16))
# sns.heatmap(corr, cmap=colormap, annot=True)
# plt.show()

# %%
# to implement a pipeline, we separate the features and target variable first

features = df_all_stats.iloc[:,3:-4] # this is a dataframe class
target_variable = df_all_stats.iloc[:,-2:-1] # this is a dataframe class

# let's change these dataframe types to arrays

X = features.to_numpy() # this is a 2D array
y = target_variable.to_numpy().ravel() # this is a 1D array
feature_names = features.columns.to_numpy()

# %% [markdown]
# ### Split train and test data

# %%
# split

from sklearn.model_selection import train_test_split
import sklearn.metrics

X_train, X_test, y_train, y_test = train_test_split(features, target_variable, stratify=y, test_size = 0.25)

# %% [markdown]
# ### Feature selection

# %%
from sklearn.feature_selection import SelectKBest, chi2, f_classif, mutual_info_classif

# since X is numerical data and y is labeled, we should use the ANOVA F-value (f_classif)

selector = SelectKBest(f_classif, k=4)
X_train_fitted = selector.fit_transform(X_train, y_train)
print('F-value scores: %s' % selector.scores_)
print('Feature index: %s' % selector.get_support(indices=True))
print('Feature names: %s' % feature_names[selector.get_support(indices=True)])
# Out:
# F-value scores: [ 174.834  725.658  717.68    63.706   47.139  622.983  968.31   622.739
#   310.782 1236.563  128.907 1872.538  812.59    97.574  831.365  379.439
#   467.389 4130.685]
# Feature index: [ 6  9 11 17]
# Feature names: ['ast' 'tov' 'pts' 'vorp']

# %%
# recursive feature elimination. chose Logistic Regression, but can use other estimators

from sklearn.feature_selection import RFE

model = LogisticRegression(solver='lbfgs', max_iter=3000)
rfe = RFE(model, n_features_to_select=4)
fit = rfe.fit(X_train, y_train)
print('Feature ranking: %s' % fit.ranking_)
print('Feature index: %s' % fit.get_support(indices=True))
print('Feature names: %s' % feature_names[fit.get_support(indices=True)])
# Out:
# Feature ranking: [14 15  8  2 11  6  7  1  4  1  3 12 10 13  5  1  9  1]
# Feature index: [ 7  9 15 17]
# Feature names: ['stl' 'tov' 'ws/48' 'vorp']

# %%
# feature importance 
from sklearn.ensemble import ExtraTreesClassifier

model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_train, y_train)
important_features = pd.Series(data=model.feature_importances_, index=feature_names)
print(important_features.sort_values(ascending=False))
# Out:
# vorp     0.138485
# per      0.115329
# pts      0.106015
# ws/48    0.077204
# tov      0.068657
# bpm      0.064534
# usg%     0.061972
# mp       0.051115
# ast      0.045036
# gs       0.043619
# stl      0.032363
# blk      0.031061
# fg%      0.030718
# trb      0.027873
# ts%      0.027473
# efg%     0.027013
# g        0.026258
# pf       0.025275
# dtype: float64

# %%
# PCA

from sklearn.decomposition import PCA

pca = PCA(n_components=4)
fit = pca.fit(X_train)
print('Explained Variance: %s' % fit.explained_variance_ratio_)
pd.DataFrame(pca.components_, columns=feature_names, index=['PC-1', 'PC-2', 'PC-3', 'PC-4'])
# Out:
# Explained Variance: [0.763 0.163 0.038 0.018]
#              g        gs        mp       fg%      efg%       trb       ast  \
# PC-1  0.586761  0.752650  0.239638  0.000829  0.000911  0.044058  0.028011
# PC-2  0.801136 -0.586393 -0.072696  0.000718  0.000985 -0.018427 -0.016516
# PC-3 -0.083432 -0.228742  0.328754  0.004706  0.005395  0.063080  0.064050
# PC-4 -0.003088  0.152463 -0.489742  0.006872  0.006938 -0.009253 -0.069594
#
#            stl       blk       tov        pf       pts       per       ts%  \
# PC-1  0.008069  0.005190  0.014940  0.014445  0.125273  0.084227  0.000999
# PC-2 -0.002911 -0.002143 -0.009374  0.000700 -0.062500 -0.002109  0.000947
# PC-3  0.015362  0.006596  0.033714  0.009854  0.344570  0.603055  0.005924
# PC-4 -0.014623  0.010394 -0.052450 -0.022047 -0.337482  0.421542  0.006180
#
#           usg%     ws/48       bpm      vorp
# PC-1  0.037753  0.001110  0.061717  0.022985
# PC-2 -0.063012  0.000630  0.014157 -0.015540
# ...

# %%
from sklearn.linear_model import Ridge

ridge = Ridge(alpha=1.0)
ridge.fit(X_train, y_train)

def show_coefs(ridge_coefficients): 
    names = ['x%s' % i for i in range(len(ridge_coefficients[0]))]
    lst = list(zip(names, feature_names, np.round(ridge_coefficients[0],3)))
    return lst

print(show_coefs(ridge.coef_))
# Out:
# [('x0', 'g', -0.0), ('x1', 'gs', -0.0), ('x2', 'mp', -0.009), ('x3', 'fg%', 0.215), ('x4', 'efg%', -0.114), ('x5', 'trb', 0.003), ('x6', 'ast', 0.004), ('x7', 'stl', -0.015), ('x8', 'blk', 0.016), ('x9', 'tov', 0.034), ('x10', 'pf', -0.006), ('x11', 'pts', 0.014), ('x12', 'per', -0.005), ('x13', 'ts%', -0.188), ('x14', 'usg%', -0.001), ('x15', 'ws/48', 0.26), ('x16', 'bpm', 0.0), ('x17', 'vorp', 0.072)]

# %%
X_train[['vorp', ]]

# %% [markdown]
# ## Select & Train a Model
#
# Train & evaluate on the training set.
# Use cross-validation.

# %%
# because this is an unbalanced dataset:

total_short_list = len(df_all_stats[df_all_stats['short_list'] == 1])
total_players = len(df_all_stats)
print('due to the imbalance, we need to beat this accuracy: ' 
      + str(round((1-total_short_list/total_players)*100, 2)) 
      + '%')
# Out:
# due to the imbalance, we need to beat this accuracy: 96.79%

# %%
# create function
from sklearn.pipeline import make_pipeline

def modelClf(clf):
    pipe = make_pipeline(MinMaxScaler(), clf)
    pipe.fit(X_train, y_train)
    return round(pipe.score(X_test, y_test)*100,2)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.tree import DecisionTreeClassifier

# %%
# Logistic Regression
log_reg_score = modelClf(LogisticRegression(solver='lbfgs'))
print('logistic regression labeling accuracy: %s' % str(log_reg_score) + '%')

# Random Forest
rf_score = modelClf(RandomForestClassifier(n_estimators=500))
print('random forest labeling accuracy: ' + str(rf_score) + '%')

# SVC
svc_score = modelClf(SVC(gamma='scale'))
print('svc labeling accuracy: ' + str(svc_score) + '%')

# KNN
knn_score = modelClf(KNeighborsClassifier())
print('knn labeling accuracy: ' + str(knn_score) + '%')
# Out:
# /Users/stephaniezhu/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/stephaniezhu/opt/anaconda3/lib/python3.7/site-packages/sklearn/pipeline.py:356: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params)
# logistic regression labeling accuracy: 98.19%
# random forest labeling accuracy: 98.35%
# svc labeling accuracy: 98.19%
# /Users/stephaniezhu/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
# temp end

# %%
df_adv_mvp = df_all_stats.copy()

# %%
X = df_sl_basic2[['VORP', 'BPM', 'PER']]
y = df_sl_basic2[['mvp']]

# %%
from sklearn.model_selection import train_test_split
import sklearn.metrics

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %% [markdown]
# ### Using cross-validation

# %% [markdown]
# ## Fine tune your model & evaluate on the test set
#
# - grid search vs. randomized search
# - ensemble methods

# %% [markdown]
# ## Present the solution

# %%
df_current = pd.read_csv('data_current_year/advanced_2020.csv')

# %%
# remove asterisks from Player names
df_current['Player'] = df_current['Player'].str.replace('*','')

# %%
x = df_current['VORP']

# %%
y_pred = logreg.predict(x.values.reshape(-1,1))

# %%
df_test2 = df_current.merge(pd.DataFrame(y_pred, columns=['pred'])
                                                   , left_index=True, right_index=True)

# %%
shortlist = df_test2[df_test2['pred'] == 1][['Player', 'VORP', 'BPM', 'PER']]

# %%
X = shortlist[['VORP', 'BPM', 'PER']]

# %%
X
# Out:
#      VORP   BPM   PER
# 11    6.0  11.5  31.7
# 117   4.9   8.5  28.3
# 191   6.2   9.1  28.2
# 243   5.5   8.5  25.9
# 254   5.1   7.8  25.2
# 290   4.8   7.1  26.2

# %%
y_pred2 = logreg2.predict(X)

# %%
df_preds = shortlist.merge(pd.DataFrame(y_pred2, columns=['pred'])
                                                   , left_index=True, right_index=True)

# %%
df_preds
# Out:
# Empty DataFrame
# Columns: [Player, VORP, BPM, PER, pred]
# Index: []
